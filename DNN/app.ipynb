# %%
import pandas as pd

# %%
# Load the dataset
file_path = '../messages.csv'
data = pd.read_csv(file_path)
data
# Out:
#                                                 subject  \
# 0               job posting - apple-iss research center
# 1                                                   NaN
# 2     query : letter frequencies for text identifica...
# 3                                                  risk
# 4                              request book information
# ...                                                 ...
# 2888                       love your profile - ysuolvpv
# 2889                 you have been asked to join kiddin
# 2890                 anglicization of composers ' names
# 2891  re : 6 . 797 , comparative method : n - ary co...
# 2892               re : american - english in australia
#
#                                                 message  label
# 0     content - length : 3386 apple-iss research cen...      0
# 1     lang classification grimes , joseph e . and ba...      0
# 2     i am posting this inquiry for sergei atamas ( ...      0
# ...

# %%
data.head()
# Out:
#                                              subject  \
# 0            job posting - apple-iss research center
# 1                                                NaN
# 2  query : letter frequencies for text identifica...
# 3                                               risk
# 4                           request book information
#
#                                              message  label
# 0  content - length : 3386 apple-iss research cen...      0
# 1  lang classification grimes , joseph e . and ba...      0
# 2  i am posting this inquiry for sergei atamas ( ...      0
# 3  a colleague and i are researching the differin...      0
# 4  earlier this morning i was on the phone with a...      0

# %%
# Drop the columns that are not useful
data['subject'].fillna('', inplace=True)

# Combine the subject and message columns
data['text'] = data['subject'] + ' ' + data['message']

# Print the first few rows of the combined text
print(data[['text', 'label']].head())
# Out:
#                                                 text  label
# 0  job posting - apple-iss research center conten...      0
# 1   lang classification grimes , joseph e . and b...      0
# 2  query : letter frequencies for text identifica...      0
# 3  risk a colleague and i are researching the dif...      0
# 4  request book information earlier this morning ...      0

# %%
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer

# Extract the text and label columns
X_train, X_test, y_train, y_test = train_test_split(data['text'], data['label'], random_state=0)

# Create TF-IDF vectorziers

ftidf_vectorizer = TfidfVectorizer(max_features=1000)
X_train_tfidf = ftidf_vectorizer.fit_transform(X_train)
X_test_tfidf = ftidf_vectorizer.transform(X_test)

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
# Create a sequential model with three layers of Dense neurons
model = Sequential([
    Dense(512, input_dim=1000, activation='relu'),
    Dense(256, activation='relu'),
    Dense(1, activation='sigmoid')
])

model

# %%
# Compile the model
model.compile(optimizer='adam', loss='binary_crossentropy',metrics=['accuracy'])

# Check the shape of the input features and labels
print("Shape of X_train:", X_train_tfidf.shape)
print("Shape of y_train:", y_train.shape)

# Check model's input shape
print("Model's expected input shape:", model.input_shape)


X_train_tfidf = X_train_tfidf.toarray()  # Convert training data
X_test_tfidf = X_test_tfidf.toarray()    # Convert test data


# Check the shape of the input features and labels
print("Shape of X_test:", X_test_tfidf.shape)
# Out:
# Shape of X_train: (2169, 1000)
# Shape of y_train: (2169,)
# Model's expected input shape: (None, 1000)
# Shape of X_test: (724, 1000)

# %%
# Train the model
history = model.fit(X_train_tfidf, y_train, epochs=310, batch_size=8,validation_data=(X_test_tfidf, y_test))
# Out:
# Epoch 1/310
# 272/272 [==============================] - 4s 12ms/step - loss: 0.0809 - accuracy: 0.9686 - val_loss: 0.0087 - val_accuracy: 0.9972
# Epoch 2/310
# 272/272 [==============================] - 3s 12ms/step - loss: 0.0032 - accuracy: 0.9991 - val_loss: 0.0134 - val_accuracy: 0.9972
# Epoch 3/310
# 272/272 [==============================] - 3s 11ms/step - loss: 2.9775e-04 - accuracy: 1.0000 - val_loss: 0.0065 - val_accuracy: 0.9986
# Epoch 4/310
# 272/272 [==============================] - 3s 11ms/step - loss: 9.9504e-05 - accuracy: 1.0000 - val_loss: 0.0068 - val_accuracy: 0.9986
# Epoch 5/310
# 272/272 [==============================] - 3s 12ms/step - loss: 5.7637e-05 - accuracy: 1.0000 - val_loss: 0.0069 - val_accuracy: 0.9986
# Epoch 6/310
# 272/272 [==============================] - 3s 12ms/step - loss: 3.4025e-05 - accuracy: 1.0000 - val_loss: 0.0074 - val_accuracy: 0.9972
# Epoch 7/310
# ...
